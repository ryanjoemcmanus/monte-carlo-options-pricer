# %% [markdown]
# # Monte Carlo Options Pricer Demo
#
# This notebook demonstrates the package API after installing the project with `pip install -e .`.

# %%
from mc_options.black_scholes import black_scholes_price, black_scholes_greeks
from mc_options.monte_carlo import price_european_option_mc

params = dict(S0=100, K=100, r=0.05, sigma=0.20, T=1.0, option_type='call')
mc = price_european_option_mc(**params, n_paths=100_000, seed=42)
bs = black_scholes_price(**params)
greeks = black_scholes_greeks(**params)
mc, bs, greeks
